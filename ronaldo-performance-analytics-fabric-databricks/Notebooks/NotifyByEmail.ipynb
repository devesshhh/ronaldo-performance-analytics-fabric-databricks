# %%
import smtplib
from email.mime.text import MIMEText

# Replace with your details
sender_email = "deveshrai162@gmail.com"
receiver_email = "deveshrai1312@gmail.com"
app_password = "hmwb raoc cohb aglu" 

# Email content
subject = "✅ Fabric Pipeline Completed"
body = "Your Microsoft Fabric pipeline has completed successfully.\n\nThank you for running it."

msg = MIMEText(body)
msg["Subject"] = subject
msg["From"] = sender_email
msg["To"] = receiver_email

# Send email via Gmail SMTP
try:
    with smtplib.SMTP_SSL("smtp.gmail.com", 465) as server:
        server.login(sender_email, app_password)
        server.sendmail(sender_email, receiver_email, msg.as_string())
    print("📧 Email sent to: deveshrai1312@gmail.com")
except Exception as e:
    print("❌ Error sending email:", str(e))
# Out:
# StatementMeta(, 27ed8737-b3a6-4b25-9544-543fc999ca0a, 4, Finished, Available, Finished)
# 📧 Email sent to: deveshrai1312@gmail.com
